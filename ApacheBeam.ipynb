# %%
# Cell 1: setup and verify MovieLens files

import os
import zipfile
import shutil

data_folder = "data/ml-latest-small"
os.makedirs(data_folder, exist_ok=True)

if "movies.csv" not in os.listdir(data_folder):
    print("movies.csv not found, trying to extract from zip...")

    zip_candidates = [
        "data/ml-latest-small.zip",
        os.path.join(data_folder, "ml-latest-small.zip"),
    ]

    zip_path = None
    for z in zip_candidates:
        if os.path.exists(z):
            zip_path = z
            break

    if zip_path is not None:
        print(f"Extracting from: {zip_path}")
        with zipfile.ZipFile(zip_path, "r") as zip_ref:
            zip_ref.extractall(data_folder)
    else:
        print("No zip file found, please check paths.")

nested = os.path.join(data_folder, "ml-latest-small")
if os.path.exists(nested):
    for file in os.listdir(nested):
        shutil.move(os.path.join(nested, file), data_folder)
    shutil.rmtree(nested)

print("Files in ml-latest-small:")
print(os.listdir(data_folder))
# Out:
# movies.csv not found, trying to extract from zip...
# Extracting from: data/ml-latest-small.zip
# Files in ml-latest-small:
# ['links.csv', 'movies.csv', 'ratings.csv', 'README.txt', 'tags.csv']

# %%
# Cell 2: install apache-beam, imports, helper functions

# !pip install apache-beam

import apache_beam as beam
from apache_beam.options.pipeline_options import PipelineOptions
import csv
import os

movies_path = "data/ml-latest-small/movies.csv"
ratings_path = "data/ml-latest-small/ratings.csv"
output_dir = "output"

def parse_csv_line(line):
    """Safely parse a CSV line using Python's csv.reader."""
    return next(csv.reader([line]))

def parse_movie(line):
    """Parse one line from movies.csv into a dict."""
    cols = parse_csv_line(line)
    if len(cols) < 3:
        return None
    
    movie_id = cols[0]
    title = cols[1]
    genres = cols[2].split("|") if cols[2] != "(no genres listed)" else []
    
    return {
        "movieId": movie_id,
        "title": title,
        "genres": genres,
    }

def parse_rating(line):
    """Parse one line from ratings.csv into a dict."""
    cols = parse_csv_line(line)
    if len(cols) < 4:
        return None
    
    try:
        rating = float(cols[2])
    except ValueError:
        return None
    
    return {
        "userId": cols[0],
        "movieId": cols[1],
        "rating": rating,
        "timestamp": cols[3],
    }

def assign_rating_band(avg):
    """Categorize movies based on avg rating."""
    if avg is None:
        return "unknown"
    if avg >= 4.0:
        return "high"
    if avg >= 3.0:
        return "medium"
    return "low"
# Out:
# Requirement already satisfied: apache-beam in d:\apachebeam_labs\venv\lib\site-packages (2.69.0)
# Requirement already satisfied: crcmod<2.0,>=1.7 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (1.7)
# Requirement already satisfied: cryptography<48.0.0,>=39.0.0 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (46.0.3)
# Requirement already satisfied: orjson<4,>=3.9.7 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (3.11.4)
# Requirement already satisfied: fastavro<2,>=0.23.6 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (1.12.1)
# Requirement already satisfied: fasteners<1.0,>=0.3 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (0.20)
# Requirement already satisfied: grpcio>=1.67.0 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (1.76.0)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (2.7.3)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (0.22.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (4.25.1)
# Requirement already satisfied: jsonpickle<4.0.0,>=3.0.0 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (3.4.2)
# Requirement already satisfied: numpy<2.3.0,>=1.14.3 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (2.2.6)
# Requirement already satisfied: objsize<0.8.0,>=0.6.1 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (0.7.1)
# Requirement already satisfied: packaging>=22.0 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (25.0)
# Requirement already satisfied: pymongo<5.0.0,>=3.8.0 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (4.15.4)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (1.26.1)
# Requirement already satisfied: protobuf!=4.0.*,!=4.21.*,!=4.22.0,!=4.23.*,!=4.24.*,<7.0.0.dev0,>=3.20.3 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (6.33.1)
# Requirement already satisfied: pydot<2,>=1.2.0 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (1.4.2)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (2.9.0.post0)
# Requirement already satisfied: pytz>=2018.3 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (2025.2)
# Requirement already satisfied: redis<6,>=5.0.0 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (5.3.1)
# Requirement already satisfied: regex>=2020.6.8 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (2025.11.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (2.32.5)
# Requirement already satisfied: sortedcontainers>=2.4.0 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (4.15.0)
# Requirement already satisfied: zstandard<1,>=0.18.0 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (0.25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=3.12 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (6.0.3)
# Requirement already satisfied: beartype<0.22.0,>=0.21.0 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (0.21.0)
# Requirement already satisfied: pyarrow<19.0.0,>=3.0.0 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (18.1.0)
# Requirement already satisfied: pyarrow-hotfix<1 in d:\apachebeam_labs\venv\lib\site-packages (from apache-beam) (0.7)
# Requirement already satisfied: cffi>=2.0.0 in d:\apachebeam_labs\venv\lib\site-packages (from cryptography<48.0.0,>=39.0.0->apache-beam) (2.0.0)
# Requirement already satisfied: docopt in d:\apachebeam_labs\venv\lib\site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam) (0.6.2)
# Requirement already satisfied: six>=1.9.0 in d:\apachebeam_labs\venv\lib\site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam) (1.17.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in d:\apachebeam_labs\venv\lib\site-packages (from httplib2<0.23.0,>=0.8->apache-beam) (3.2.5)
# Requirement already satisfied: attrs>=22.2.0 in d:\apachebeam_labs\venv\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\apachebeam_labs\venv\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\apachebeam_labs\venv\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\apachebeam_labs\venv\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam) (0.29.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in d:\apachebeam_labs\venv\lib\site-packages (from pymongo<5.0.0,>=3.8.0->apache-beam) (2.8.0)
# Requirement already satisfied: PyJWT>=2.9.0 in d:\apachebeam_labs\venv\lib\site-packages (from redis<6,>=5.0.0->apache-beam) (2.10.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\apachebeam_labs\venv\lib\site-packages (from requests<3.0.0,>=2.32.4->apache-beam) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\apachebeam_labs\venv\lib\site-packages (from requests<3.0.0,>=2.32.4->apache-beam) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\apachebeam_labs\venv\lib\site-packages (from requests<3.0.0,>=2.32.4->apache-beam) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\apachebeam_labs\venv\lib\site-packages (from requests<3.0.0,>=2.32.4->apache-beam) (2025.11.12)
# Requirement already satisfied: pycparser in d:\apachebeam_labs\venv\lib\site-packages (from cffi>=2.0.0->cryptography<48.0.0,>=39.0.0->apache-beam) (2.23)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Cell 3: Apache Beam pipeline (movie & genre stats + filters + top 10 genres)

os.makedirs(output_dir, exist_ok=True)

pipeline_options = PipelineOptions(flags=[], save_main_session=True)

with beam.Pipeline(options=pipeline_options) as p:

    movies = (
        p
        | "Read Movies CSV" >> beam.io.ReadFromText(movies_path, skip_header_lines=1)
        | "Parse Movies" >> beam.Map(parse_movie)
        | "Keep Valid Movies" >> beam.Filter(lambda m: m is not None)
        | "Movies as KV" >> beam.Map(lambda m: (m["movieId"], m))
    )

    ratings = (
        p
        | "Read Ratings CSV" >> beam.io.ReadFromText(ratings_path, skip_header_lines=1)
        | "Parse Ratings" >> beam.Map(parse_rating)
        | "Keep Valid Ratings" >> beam.Filter(lambda r: r is not None)
        | "MovieId -> Rating" >> beam.Map(lambda r: (r["movieId"], r["rating"]))
    )

    movie_avg = (
        ratings
        | "Mean Rating per Movie" >> beam.CombinePerKey(beam.combiners.MeanCombineFn())
    )

    movie_count = (
        ratings
        | "Count Ratings per Movie" >> beam.combiners.Count.PerKey()
    )

    movie_stats = (
        {"avg": movie_avg, "count": movie_count}
        | "Join Avg & Count" >> beam.CoGroupByKey()
        | "Build Movie Stats Dict" >> beam.Map(
            lambda kv: (
                kv[0],
                {
                    "avg_rating": round(kv[1]["avg"][0], 2) if kv[1]["avg"] else None,
                    "num_ratings": kv[1]["count"][0] if kv[1]["count"] else 0,
                },
            )
        )
    )

    movie_summary = (
        {"movie_info": movies, "rating_stats": movie_stats}
        | "Join Movies & Stats" >> beam.CoGroupByKey()
        | "Build Movie Summary Dict" >> beam.Map(
            lambda kv: {
                "movieId": kv[0],
                "title": kv[1]["movie_info"][0]["title"]
                if kv[1]["movie_info"] else None,
                "genres": kv[1]["movie_info"][0]["genres"]
                if kv[1]["movie_info"] else [],
                "avg_rating": kv[1]["rating_stats"][0]["avg_rating"]
                if kv[1]["rating_stats"] else None,
                "num_ratings": kv[1]["rating_stats"][0]["num_ratings"]
                if kv[1]["rating_stats"] else 0,
            }
        )
        
        | "Keep Popular Movies" >> beam.Filter(lambda d: d["num_ratings"] >= 50)
        | "Assign Rating Band" >> beam.Map(
            lambda d: {**d, "rating_band": assign_rating_band(d["avg_rating"])}
        )
        
    )

    genre_stats = (
        movie_summary
        | "Expand Genres" >> beam.FlatMap(
            lambda d: [
                (genre, d["avg_rating"])
                for genre in d["genres"]
                if d["avg_rating"] is not None
            ]
        )
    )

    genre_avg = (
        genre_stats
        | "Mean Rating per Genre" >> beam.CombinePerKey(beam.combiners.MeanCombineFn())
    )

    genre_count = (
        genre_stats
        | "Count Movies per Genre" >> beam.combiners.Count.PerKey()
    )

    genre_summary = (
        {"avg": genre_avg, "count": genre_count}
        | "Join Genre Avg & Count" >> beam.CoGroupByKey()
        | "Build Genre Summary Dict" >> beam.Map(
            lambda kv: {
                "genre": kv[0],
                "avg_rating": round(kv[1]["avg"][0], 2) if kv[1]["avg"] else None,
                "num_rated_movies": kv[1]["count"][0] if kv[1]["count"] else 0,
            }
        )
    )

    _ = (
        movie_summary
        | "Movie Summary -> String" >> beam.Map(lambda d: str(d))
        | "Write Movie Summary" >> beam.io.WriteToText(
            file_path_prefix=os.path.join(output_dir, "movie_rating_summary"),
            file_name_suffix=".txt",
            shard_name_template=""
        )
    )

    _ = (
        genre_summary
        | "Genre Summary -> String" >> beam.Map(lambda d: str(d))
        | "Write Genre Summary" >> beam.io.WriteToText(
            file_path_prefix=os.path.join(output_dir, "genre_rating_summary"),
            file_name_suffix=".txt",
            shard_name_template=""
        )
    )

    top10_genres = (
        genre_summary
        | "Map for Sorting" >> beam.Map(lambda d: (d["avg_rating"], d))
        | "Top 10 Genres" >> beam.combiners.Top.Of(10, key=lambda x: x[0])
        | "Extract Genre Dicts" >> beam.FlatMap(lambda items: [i[1] for i in items])
    )

    _ = (
        top10_genres
        | "Top 10 -> String" >> beam.Map(lambda d: str(d))
        | "Write Top 10 Genres" >> beam.io.WriteToText(
            file_path_prefix=os.path.join(output_dir, "top10_genres_by_rating"),
            file_name_suffix=".txt",
            shard_name_template=""
        )
    )
# Out:
# WARNING:apache_beam.runners.interactive.interactive_environment:Dependencies required for Interactive Beam PCollection visualization are not available, please use: `pip install apache-beam[interactive]` to install necessary dependencies to enable all data visualization features.
# WARNING:apache_beam.transforms.core:('No iterator is returned by the process method in %s.', <class 'apache_beam.transforms.combiners._TopPerBundle'>)

# %%
# Cell 4: inspect output files

print("Output files:", os.listdir(output_dir))

print("\nSample movie summary lines:")
with open(os.path.join(output_dir, "movie_rating_summary.txt")) as f:
    for i, line in enumerate(f):
        if i >= 5:
            break
        print(line.strip())

print("\nSample genre summary lines:")
with open(os.path.join(output_dir, "genre_rating_summary.txt")) as f:
    for i, line in enumerate(f):
        if i >= 5:
            break
        print(line.strip())

print("\nTop 10 genres by rating:")
with open(os.path.join(output_dir, "top10_genres_by_rating.txt")) as f:
    for i, line in enumerate(f):
        if i >= 10:
            break
        print(line.strip())
# Out:
# Output files: ['genre_rating_summary.txt', 'movie_rating_summary.txt', 'top10_genres_by_rating.txt']
#
# Sample movie summary lines:
# {'movieId': '1', 'title': 'Toy Story (1995)', 'genres': ['Adventure', 'Animation', 'Children', 'Comedy', 'Fantasy'], 'avg_rating': 3.92, 'num_ratings': 215, 'rating_band': 'medium'}
# {'movieId': '2', 'title': 'Jumanji (1995)', 'genres': ['Adventure', 'Children', 'Fantasy'], 'avg_rating': 3.43, 'num_ratings': 110, 'rating_band': 'medium'}
# {'movieId': '3', 'title': 'Grumpier Old Men (1995)', 'genres': ['Comedy', 'Romance'], 'avg_rating': 3.26, 'num_ratings': 52, 'rating_band': 'medium'}
# {'movieId': '6', 'title': 'Heat (1995)', 'genres': ['Action', 'Crime', 'Thriller'], 'avg_rating': 3.95, 'num_ratings': 102, 'rating_band': 'medium'}
# {'movieId': '7', 'title': 'Sabrina (1995)', 'genres': ['Comedy', 'Romance'], 'avg_rating': 3.19, 'num_ratings': 54, 'rating_band': 'medium'}
#
# Sample genre summary lines:
# {'genre': 'Adventure', 'avg_rating': 3.62, 'num_rated_movies': 132}
# {'genre': 'Animation', 'avg_rating': 3.72, 'num_rated_movies': 32}
# {'genre': 'Children', 'avg_rating': 3.63, 'num_rated_movies': 47}
# {'genre': 'Comedy', 'avg_rating': 3.54, 'num_rated_movies': 181}
# {'genre': 'Fantasy', 'avg_rating': 3.64, 'num_rated_movies': 66}
#
# Top 10 genres by rating:
# {'genre': 'Film-Noir', 'avg_rating': 3.99, 'num_rated_movies': 4}
# {'genre': 'War', 'avg_rating': 3.89, 'num_rated_movies': 19}
# {'genre': 'Mystery', 'avg_rating': 3.83, 'num_rated_movies': 38}
# {'genre': 'Crime', 'avg_rating': 3.81, 'num_rated_movies': 87}
# {'genre': 'Drama', 'avg_rating': 3.8, 'num_rated_movies': 166}
# {'genre': 'IMAX', 'avg_rating': 3.76, 'num_rated_movies': 28}
# {'genre': 'Animation', 'avg_rating': 3.72, 'num_rated_movies': 32}
# {'genre': 'Musical', 'avg_rating': 3.65, 'num_rated_movies': 21}
# {'genre': 'Thriller', 'avg_rating': 3.65, 'num_rated_movies': 121}
# {'genre': 'Fantasy', 'avg_rating': 3.64, 'num_rated_movies': 66}
